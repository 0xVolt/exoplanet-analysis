# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv(r'C:\Users\deshi\Code\exoplanet-analysis\PS_2022.11.06_10.27.50.csv', index_col='loc_rowid')
# Out:
#              pl_name hostname  default_flag  sy_snum  sy_pnum  \
# loc_rowid
# 1           11 Com b   11 Com             1        2        1
# 2           11 Com b   11 Com             0        2        1
# 3           11 UMi b   11 UMi             0        1        1
# 4           11 UMi b   11 UMi             0        1        1
# 5           11 UMi b   11 UMi             1        1        1
# ...              ...      ...           ...      ...      ...
# 33715      ups And d  ups And             0        2        3
# 33716      ups And d  ups And             0        2        3
# 33717      ups Leo b  ups Leo             1        1        1
# 33718       xi Aql b   xi Aql             0        1        1
# 33719       xi Aql b   xi Aql             1        1        1
#
#            discoverymethod  disc_year                           disc_facility  \
# loc_rowid
# 1          Radial Velocity       2007                        Xinglong Station
# ...
